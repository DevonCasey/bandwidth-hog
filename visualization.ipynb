# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
import tk 
from tkinter.filedialog import askopenfilename

# %%
plt.rcParams["figure.figsize"] = [7,3.5]
plt.rcParams['figure.autolayout'] = True
columns = ['Hostname', 'NIC', 'Bandwidth', 'Time']
filename = askopenfilename()
df = pd.read_csv(filename , usecols=columns)
print("Selected: " + filename)
# Out:
# Selected: C:/Users/dcasey/Documents/Work-Programming/Powershell/bandwidth-hog/W-01099.csv

# %%
df
# Out:
#     Hostname                                       NIC  Bandwidth   Time
# 0        NaN                                       NaN        NaN    NaN
# 1    W-01099  Intel[R] Ethernet Connection [7] I219-LM       26.1    0.0
# 2    W-01099  Intel[R] Ethernet Connection [7] I219-LM       26.9    1.0
# 3    W-01099  Intel[R] Ethernet Connection [7] I219-LM       26.2    2.0
# 4    W-01099  Intel[R] Ethernet Connection [7] I219-LM       24.2    3.0
# ..       ...                                       ...        ...    ...
# 497  W-01099  Intel[R] Ethernet Connection [7] I219-LM       24.8  496.0
# 498  W-01099  Intel[R] Ethernet Connection [7] I219-LM       23.9  497.0
# 499  W-01099  Intel[R] Ethernet Connection [7] I219-LM       24.2  498.0
# 500  W-01099  Intel[R] Ethernet Connection [7] I219-LM       24.5  499.0
# 501  W-01099  Intel[R] Ethernet Connection [7] I219-LM       25.0  500.0
#
# [502 rows x 4 columns]

# %%
df = df.drop(columns=['Hostname','NIC'])
df = df.tail(-1)
df
# Out:
#      Bandwidth   Time
# 1         26.1    0.0
# 2         26.9    1.0
# 3         26.2    2.0
# 4         24.2    3.0
# 5         26.2    4.0
# ..         ...    ...
# 497       24.8  496.0
# 498       23.9  497.0
# 499       24.2  498.0
# 500       24.5  499.0
# 501       25.0  500.0
#
# [501 rows x 2 columns]

# %%
x_ticks = 50
y_ticks = 5
fig, ax = plt.subplots(1,1)
ax.plot(df.Time, df.Bandwidth, label='Server 1')
ax.xaxis.set_major_locator(ticker.MultipleLocator(x_ticks))
ax.yaxis.set_major_locator(ticker.MultipleLocator(y_ticks))
plt.legend()
plt.show()
