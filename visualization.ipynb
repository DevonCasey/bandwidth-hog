# %%
import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.ticker as ticker
import tk 
from tkinter.filedialog import askopenfilename

# %%
plt.rcParams["figure.figsize"] = [7,3.5]
plt.rcParams['figure.autolayout'] = True
columns = ['Hostname', 'NIC', 'Bandwidth', 'Time']
filename = askopenfilename()
df = pd.read_csv(filename , usecols=columns)
# df = pd.read_csv(r'C:\Users\dcasey\Documents\Work-Programming\Powershell\playground\W-01099.csv', usecols=columns)
print("Selected: " + filename)

# %%
df
# Out:
#     Hostname                                       NIC  Bandwidth   Time
# 0        NaN                                       NaN        NaN    NaN
# 1    W-01099  Intel[R] Ethernet Connection [7] I219-LM        0.0    0.0
# 2    W-01099  Intel[R] Ethernet Connection [7] I219-LM        0.0    1.0
# 3    W-01099  Intel[R] Ethernet Connection [7] I219-LM        0.0    2.0
# 4    W-01099  Intel[R] Ethernet Connection [7] I219-LM        0.0    3.0
# ..       ...                                       ...        ...    ...
# 497  W-01099  Intel[R] Ethernet Connection [7] I219-LM       25.4  496.0
# 498  W-01099  Intel[R] Ethernet Connection [7] I219-LM       25.6  497.0
# 499  W-01099  Intel[R] Ethernet Connection [7] I219-LM       25.6  498.0
# 500  W-01099  Intel[R] Ethernet Connection [7] I219-LM       25.7  499.0
# 501  W-01099  Intel[R] Ethernet Connection [7] I219-LM       26.3  500.0
#
# [502 rows x 4 columns]

# %%
df = df.drop(columns=['Hostname','NIC'])
df = df.tail(-1)
df
# Out:
#      Bandwidth   Time
# 1          0.0    0.0
# 2          0.0    1.0
# 3          0.0    2.0
# 4          0.0    3.0
# 5          0.0    4.0
# ..         ...    ...
# 497       25.4  496.0
# 498       25.6  497.0
# 499       25.6  498.0
# 500       25.7  499.0
# 501       26.3  500.0
#
# [501 rows x 2 columns]

# %%
df
# Out:
#      Bandwidth   Time
# 1          0.0    0.0
# 2          0.0    1.0
# 3          0.0    2.0
# 4          0.0    3.0
# 5          0.0    4.0
# ..         ...    ...
# 497       25.4  496.0
# 498       25.6  497.0
# 499       25.6  498.0
# 500       25.7  499.0
# 501       26.3  500.0
#
# [501 rows x 2 columns]

# %%
x_ticks = 50
y_ticks = 5
fig, ax = plt.subplots(1,1)
ax.plot(df.Time, df.Bandwidth, label='Server 1')
ax.xaxis.set_major_locator(ticker.MultipleLocator(x_ticks))
ax.yaxis.set_major_locator(ticker.MultipleLocator(y_ticks))
plt.legend()
plt.show()
